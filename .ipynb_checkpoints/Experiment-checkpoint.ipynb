# %%
import pickle
import pandas as pd
from sklearn.neighbors import NearestNeighbors

# %%
# user id to recommend restaurants for
USER_ID = "u00000"

# %%
# load model from pickle file
with open("../model.pkl", "rb") as f:
    model: NearestNeighbors = pickle.load(f)
# Out:
# /Users/kuangsmacbook/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:376: InconsistentVersionWarning: Trying to unpickle estimator NearestNeighbors from version 1.3.2 when using version 1.4.0. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
# Log the model with MLflow
import mlflow
# mlflow.set_tracking_uri("file:///Users/kuangsmacbook/Desktop/Works/LINEMAN\ MLE/attachment/server/mlruns")
with mlflow.start_run():
    mlflow.sklearn.log_model(model, "recommend")
# Out:
# 2024/02/04 18:25:52 WARNING mlflow.sklearn: Model was missing function: predict. Not logging python_function flavor!
# /Users/kuangsmacbook/Library/Python/3.9/lib/python/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In [4], line 5
#       3 # mlflow.set_tracking_uri("file:///Users/kuangsmacbook/Desktop/Works/LINEMAN\ MLE/attachment/server/mlruns")
#       4 with mlflow.start_run():
# ----> 5     mlflow.sklearn.log_model(model, "recommend")
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/sklearn/__init__.py:411, in log_model(sk_model, artifact_path, conda_env, code_paths, serialization_format, registered_model_name, signature, input_example, await_registration_for, pip_requirements, extra_pip_requirements, pyfunc_predict_fn, metadata)
#     331 @format_docstring(LOG_MODEL_PARAM_DOCS.format(package_name="scikit-learn"))
#     332 def log_model(
#     333     sk_model,
#    (...)
#     345     metadata=None,
#     346 ):
#     347     """
#     348     Log a scikit-learn model as an MLflow artifact for the current run. Produces an MLflow Model
#     349     containing the following flavors:
#    (...)
#     409
#     410     """
# --> 411     return Model.log(
#     412         artifact_path=artifact_path,
#     413         flavor=mlflow.sklearn,
#     414         sk_model=sk_model,
#     415         conda_env=conda_env,
#     416         code_paths=code_paths,
#     417         serialization_format=serialization_format,
#     418         registered_model_name=registered_model_name,
#     419         signature=signature,
#     420         input_example=input_example,
#     421         await_registration_for=await_registration_for,
#     422         pip_requirements=pip_requirements,
#     423         extra_pip_requirements=extra_pip_requirements,
#     424         pyfunc_predict_fn=pyfunc_predict_fn,
#     425         metadata=metadata,
#     426     )
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/models/model.py:623, in Model.log(cls, artifact_path, flavor, registered_model_name, await_registration_for, metadata, run_id, **kwargs)
#     621     _logger.warning(_LOG_MODEL_MISSING_SIGNATURE_WARNING)
#     622 flavor.save_model(path=local_path, mlflow_model=mlflow_model, **kwargs)
# --> 623 mlflow.tracking.fluent.log_artifacts(local_path, mlflow_model.artifact_path, run_id)
#     624 try:
#     625     mlflow.tracking.fluent._record_logged_model(mlflow_model, run_id)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/tracking/fluent.py:1046, in log_artifacts(local_dir, artifact_path, run_id)
#    1016 """
#    1017 Log all the contents of a local directory as artifacts of the run. If no run is active,
#    1018 this method will create a new active run.
#    (...)
#    1043         mlflow.log_artifacts("data", artifact_path="states")
#    1044 """
#    1045 run_id = run_id or _get_or_start_run().info.run_id
# -> 1046 MlflowClient().log_artifacts(run_id, local_dir, artifact_path)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/tracking/client.py:1195, in MlflowClient.log_artifacts(self, run_id, local_dir, artifact_path)
#    1151 def log_artifacts(
#    1152     self, run_id: str, local_dir: str, artifact_path: Optional[str] = None
#    1153 ) -> None:
#    1154     """
#    1155     Write a directory of files to the remote ``artifact_uri``.
#    1156
#    (...)
#    1193         is_dir: True
#    1194     """
# -> 1195     self._tracking_client.log_artifacts(run_id, local_dir, artifact_path)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/tracking/_tracking_service/client.py:538, in TrackingServiceClient.log_artifacts(self, run_id, local_dir, artifact_path)
#     531 def log_artifacts(self, run_id, local_dir, artifact_path=None):
#     532     """
#     533     Write a directory of files to the remote ``artifact_uri``.
#     534
#     535     :param local_dir: Path to the directory of files to write.
#     536     :param artifact_path: If provided, the directory in ``artifact_uri`` to write to.
#     537     """
# --> 538     self._get_artifact_repo(run_id).log_artifacts(local_dir, artifact_path)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/tracking/_tracking_service/client.py:506, in TrackingServiceClient._get_artifact_repo(self, run_id)
#     502 run = self.get_run(run_id)
#     503 artifact_uri = add_databricks_profile_info_to_artifact_uri(
#     504     run.info.artifact_uri, self.tracking_uri
#     505 )
# --> 506 artifact_repo = get_artifact_repository(artifact_uri)
#     507 # Cache the artifact repo to avoid a future network call, removing the oldest
#     508 # entry in the cache if there are too many elements
#     509 if len(TrackingServiceClient._artifact_repos_cache) > 1024:
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/store/artifact/artifact_repository_registry.py:117, in get_artifact_repository(artifact_uri)
#     107 def get_artifact_repository(artifact_uri: str) -> ArtifactRepository:
#     108     """Get an artifact repository from the registry based on the scheme of artifact_uri
#     109
#     110     :param artifact_uri: The artifact store URI. This URI is used to select which artifact
#    (...)
#     115              requirements.
#     116     """
# --> 117     return _artifact_repository_registry.get_artifact_repository(artifact_uri)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/store/artifact/artifact_repository_registry.py:74, in ArtifactRepositoryRegistry.get_artifact_repository(self, artifact_uri)
#      69 if repository is None:
#      70     raise MlflowException(
#      71         f"Could not find a registered artifact repository for: {artifact_uri}. "
#      72         f"Currently registered schemes are: {list(self._registry.keys())}"
#      73     )
# ---> 74 return repository(artifact_uri)
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/store/artifact/mlflow_artifacts_repo.py:45, in MlflowArtifactsRepository.__init__(self, artifact_uri)
#      44 def __init__(self, artifact_uri):
# ---> 45     super().__init__(self.resolve_uri(artifact_uri, get_tracking_uri()))
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/store/artifact/mlflow_artifacts_repo.py:59, in MlflowArtifactsRepository.resolve_uri(cls, artifact_uri, tracking_uri)
#      56 _validate_port_mapped_to_hostname(uri_parse)
#      58 # Check that tracking uri is http or https
# ---> 59 _validate_uri_scheme(track_parse.scheme)
#      61 if uri_parse.path == "/":  # root directory; build simple path
#      62     resolved = f"{base_url}{uri_parse.path}"
#
# File ~/Library/Python/3.9/lib/python/site-packages/mlflow/store/artifact/mlflow_artifacts_repo.py:35, in _validate_uri_scheme(scheme)
#      33 allowable_schemes = {"http", "https"}
#      34 if scheme not in allowable_schemes:
# ---> 35     raise MlflowException(
#      36         f"The configured tracking uri scheme: '{scheme}' is invalid for use with the proxy "
#      37         f"mlflow-artifact scheme. The allowed tracking schemes are: {allowable_schemes}"
#      38     )
#
# MlflowException: The configured tracking uri scheme: 'file' is invalid for use with the proxy mlflow-artifact scheme. The allowed tracking schemes are: {'http', 'https'}

# %%
# load user and restaurant data
user_df = pd.read_parquet("user.small.parquet")
restaurant_df = pd.read_parquet("restaurant.parquet").set_index("index")

# %%
user_df.head()
# Out:
#   user_id  feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0  u00000   0.193018   1.235771   0.478129   0.056068   0.798870   0.942501
# 1  u00001   0.542445   0.061676  -0.172018   0.366714   0.690263   0.565948
# 2  u00002   0.501249   1.194607   0.750967  -0.078167   0.361179   0.124189
# 3  u00003   0.613723  -0.652035   1.161827   0.122698   0.828054  -0.296040
# 4  u00004   0.179650   0.166768   0.337015   0.594367   0.897039   0.858783
#
#    feature_6  feature_7  feature_8  ...  feature_990  feature_991  \
# 0  -0.186956  -0.186927  -0.137488  ...     0.289670     0.529229
# 1   0.030949   0.478960   0.033966  ...    -0.564581     1.279485
# 2   0.736151   1.427973  -0.676132  ...    -0.185844    -0.247236
# 3   0.563028   0.711285   0.097485  ...     0.720368     0.070521
# 4  -0.523686   0.813889   0.517246  ...     0.404695     0.707832
#
#    feature_992  feature_993  feature_994  feature_995  feature_996  \
# 0     0.658945     0.313935     1.343077    -0.160149     1.796040
# 1    -0.600161    -0.370372     1.984003     1.414539     1.877632
# 2     1.687951     0.849775     0.671021    -0.654202    -0.118870
# 3     0.338198     0.885493     0.889271     0.778233     1.164597
# 4     0.700675     1.538892     0.114889     0.793582    -0.071324
#
#    feature_997  feature_998  feature_999
# 0     0.078384     0.460348     0.228150
# 1     1.124837     2.273370     1.369663
# 2     0.419687     0.391202    -0.808181
# 3     0.572195     0.062597    -0.822071
# 4     1.282532    -0.052153     0.395376
#
# [5 rows x 1001 columns]

# %%
user_df.shape
# Out:
# (10, 1001)

# %%
restaurant_df.head()
# Out:
#       restaurant_id            latitude           longitude
# index
# 0             r0000  13.844851141246949   100.3086836106867
# 1             r0001  13.781825896541061  100.84977532273388
# 2             r0002  13.883572268183674   100.3085459374542
# 3             r0003  14.066725452665281   100.7256760943531
# 4             r0004  13.961173933525883  100.39580661948798

# %%
model.get_params()
# Out:
# {'algorithm': 'auto',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': None,
#  'n_neighbors': 5,
#  'p': 2,
#  'radius': 1.0}

# %%
model.effective_metric_
# Out:
# 'euclidean'

# %%
user_df[user_df["user_id"] == USER_ID].drop(columns="user_id")
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   0.193018   1.235771   0.478129   0.056068    0.79887   0.942501
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_990  feature_991  \
# 0  -0.186956  -0.186927  -0.137488   0.413889  ...      0.28967     0.529229
#
#    feature_992  feature_993  feature_994  feature_995  feature_996  \
# 0     0.658945     0.313935     1.343077    -0.160149      1.79604
#
#    feature_997  feature_998  feature_999
# 0     0.078384     0.460348      0.22815
#
# [1 rows x 1000 columns]

# %%
# find 20 nearest neighbors to be recommend restaurants
difference, ind = model.kneighbors(
    user_df[user_df["user_id"] == USER_ID].drop(columns="user_id"), n_neighbors=20
)

# %%
difference
# Out:
# array([[23.66758003, 23.80081254, 23.83828907, 24.07205225, 24.16645254,
#         24.18236662, 24.22441798, 24.23519259, 24.23628432, 24.26967065,
#         24.27378404, 24.28877668, 24.29956383, 24.30405023, 24.30567711,
#         24.33704798, 24.34151423, 24.34254504, 24.35122189, 24.35462439]])

# %%
ind
# Out:
# array([[1737, 2116,  862, 1060, 5083, 4855, 7495, 7182, 9669, 8749, 2316,
#         2159, 4255, 7596, 7523,  782, 7075, 2751, 3382, 9548]])

# %%
ind.shape
# Out:
# (1, 20)

# %%
difference.shape
# Out:
# (1, 20)

# %%
# get restaurant id from restaurant indices returned from the model
recommend_df = restaurant_df.loc[ind[0]]

# %%
recommend_df
# Out:
#       restaurant_id            latitude           longitude
# index
# 1737          r1737  13.629531575765236  100.75870051163373
# 2116          r2116   13.73119735587392  100.56817065841395
# 862           r0862  13.919599015060994  100.72259887691091
# 1060          r1060  13.920823054026256  100.43834135327354
# 5083          r5083  14.056428831746032  100.84463908830615
# 4855          r4855  13.591753268818621  100.81991308469668
# 7495          r7495  13.948798704378671  100.81459459201477
# 7182          r7182  13.772837613569491  100.32849058764407
# 9669          r9669  13.922821220460014  100.58332900886525
# 8749          r8749  14.023339052429405   100.7799235369726
# 2316          r2316  13.763568876627206  100.32913464429035
# 2159          r2159  14.160039595762557  100.49612768106282
# 4255          r4255  14.062879140158575  100.57137546887665
# 7596          r7596   14.13693988171087   100.4777620062772
# 7523          r7523  13.626370859366961  100.45770640627735
# 782           r0782  13.739286559566908  100.84959476903987
# 7075          r7075  13.636104606431502  100.85685888296332
# 2751          r2751  14.154504335916327  100.66435168450307
# 3382          r3382  13.698560938822412  100.57599261514814
# 9548          r9548  13.620291611391675  100.64720295627905

# %%
# set distance as restaurant score
recommend_df["difference"] = difference[0]

# %%
recommend_df
# Out:
#       restaurant_id            latitude           longitude  difference
# index
# 1737          r1737  13.629531575765236  100.75870051163373   23.667580
# 2116          r2116   13.73119735587392  100.56817065841395   23.800813
# 862           r0862  13.919599015060994  100.72259887691091   23.838289
# 1060          r1060  13.920823054026256  100.43834135327354   24.072052
# 5083          r5083  14.056428831746032  100.84463908830615   24.166453
# 4855          r4855  13.591753268818621  100.81991308469668   24.182367
# 7495          r7495  13.948798704378671  100.81459459201477   24.224418
# 7182          r7182  13.772837613569491  100.32849058764407   24.235193
# 9669          r9669  13.922821220460014  100.58332900886525   24.236284
# 8749          r8749  14.023339052429405   100.7799235369726   24.269671
# 2316          r2316  13.763568876627206  100.32913464429035   24.273784
# 2159          r2159  14.160039595762557  100.49612768106282   24.288777
# 4255          r4255  14.062879140158575  100.57137546887665   24.299564
# 7596          r7596   14.13693988171087   100.4777620062772   24.304050
# 7523          r7523  13.626370859366961  100.45770640627735   24.305677
# 782           r0782  13.739286559566908  100.84959476903987   24.337048
# 7075          r7075  13.636104606431502  100.85685888296332   24.341514
# 2751          r2751  14.154504335916327  100.66435168450307   24.342545
# 3382          r3382  13.698560938822412  100.57599261514814   24.351222
# 9548          r9548  13.620291611391675  100.64720295627905   24.354624

# %%
# print the result in json format
print(recommend_df[["restaurant_id", "difference"]].to_json(orient="records", indent=2))
# Out:
# [
#   {
#     "restaurant_id":"r1737",
#     "difference":23.6675800283
#   },
#   {
#     "restaurant_id":"r2116",
#     "difference":23.8008125402
#   },
#   {
#     "restaurant_id":"r0862",
#     "difference":23.8382890655
#   },
#   {
#     "restaurant_id":"r1060",
#     "difference":24.0720522494
#   },
#   {
#     "restaurant_id":"r5083",
#     "difference":24.166452545
#   },
#   {
#     "restaurant_id":"r4855",
#     "difference":24.182366617
#   },
#   {
#     "restaurant_id":"r7495",
#     "difference":24.2244179801
#   },
#   {
#     "restaurant_id":"r7182",
#     "difference":24.2351925876
#   },
#   {
#     "restaurant_id":"r9669",
#     "difference":24.2362843205
#   },
#   {
#     "restaurant_id":"r8749",
#     "difference":24.2696706463
#   },
#   {
#     "restaurant_id":"r2316",
#     "difference":24.2737840441
#   },
#   {
#     "restaurant_id":"r2159",
#     "difference":24.2887766768
#   },
#   {
#     "restaurant_id":"r4255",
#     "difference":24.2995638295
#   },
#   {
#     "restaurant_id":"r7596",
#     "difference":24.3040502318
#   },
#   {
#     "restaurant_id":"r7523",
#     "difference":24.3056771101
#   },
#   {
#     "restaurant_id":"r0782",
#     "difference":24.3370479842
#   },
#   {
#     "restaurant_id":"r7075",
#     "difference":24.3415142344
#   },
#   {
#     "restaurant_id":"r2751",
#     "difference":24.3425450391
#   },
#   {
#     "restaurant_id":"r3382",
#     "difference":24.3512218859
#   },
#   {
#     "restaurant_id":"r9548",
#     "difference":24.3546243861
#   }
# ]

# %%
request = pd.read_parquet("request.parquet")

# %%
request
# Out:
#      user_id   latitude   longitude  size  sort_dis  max_dis
# 0     u83153  14.068817  100.646536    50       0.0   5000.0
# 1     u45712  14.109562  100.698690    50       1.0   5000.0
# 2     u52829  13.727387  100.830825    50       1.0   5000.0
# 3     u11570  13.921809  100.468203    20       1.0   5000.0
# 4     u99991  13.804917  100.682749    50       NaN   5000.0
# ...      ...        ...         ...   ...       ...      ...
# 1995  u26540  13.924127  100.611641    50       0.0  10000.0
# 1996  u39495  13.710599  100.714934    50       NaN      NaN
# 1997  u62643  13.995389  100.403283    50       1.0   5000.0
# 1998  u07949  13.683828  100.343557    50       0.0   5000.0
# 1999  u40099  13.988415  100.432730    20       NaN  10000.0
#
# [2000 rows x 6 columns]

# %%
request['size'] = request['size'].astype("int64")

# %%
import numpy as np
print(np.isnan(request[request['max_dis'].isna()].iloc[0, -1]) == False)
# Out:
# False

# %%
import mlflow
import uuid

# %%
mlflow.sklearn.autolog()

# %%
model = mlflow.sklearn.load_model("runs:/20667a37d29345be907ccc4007dd9978/recommend")

# %%
difference, ind = model.kneighbors(
    user_df[user_df["user_id"] == USER_ID].drop(columns="user_id"), n_neighbors=20
)

# %%
difference
# Out:
# array([[23.66758003, 23.80081254, 23.83828907, 24.07205225, 24.16645254,
#         24.18236662, 24.22441798, 24.23519259, 24.23628432, 24.26967065,
#         24.27378404, 24.28877668, 24.29956383, 24.30405023, 24.30567711,
#         24.33704798, 24.34151423, 24.34254504, 24.35122189, 24.35462439]])

# %%
import geopy

# %%
# Step 4: Calculate the displacement between user and restaurants
recommended_restaurants = []
for idx, diff in zip(ind[0], difference[0]):
    restaurant = restaurant_df.loc[idx]
    if restaurant.any():
        coords_user = (14.068817, 100.646536)
        coords_restaurant = (restaurant.latitude, restaurant.longitude)
        displacement = int(geopy.distance.geodesic(coords_user, coords_restaurant).m)
        
        if displacement <= 30000:
            recommended_restaurants.append(
                {
                    "id": str(idx),
                    "difference": float(diff),
                    "displacement": displacement
                }
            )

# %%
recommended_restaurants
# Out:
# [{'id': '862', 'difference': 23.838289065463954, 'displacement': 18441},
#  {'id': '1060', 'difference': 24.072052249370532, 'displacement': 27821},
#  {'id': '5083', 'difference': 24.166452544984395, 'displacement': 21439},
#  {'id': '7495', 'difference': 24.224417980096238, 'displacement': 22493},
#  {'id': '9669', 'difference': 24.23628432046833, 'displacement': 17536},
#  {'id': '8749', 'difference': 24.269670646297847, 'displacement': 15260},
#  {'id': '2159', 'difference': 24.288776676754686, 'displacement': 19121},
#  {'id': '4255', 'difference': 24.299563829541146, 'displacement': 8144},
#  {'id': '7596', 'difference': 24.304050231792964, 'displacement': 19722},
#  {'id': '2751', 'difference': 24.34254503906854, 'displacement': 9673}]

# %%
model.set_params(n_jobs = -1, algorithm='kd_tree')
# Out:
# NearestNeighbors(algorithm='kd_tree', n_jobs=-1)

# %%
model.get_params()
# Out:
# {'algorithm': 'kd_tree',
#  'leaf_size': 30,
#  'metric': 'minkowski',
#  'metric_params': None,
#  'n_jobs': -1,
#  'n_neighbors': 5,
#  'p': 2,
#  'radius': 1.0}
